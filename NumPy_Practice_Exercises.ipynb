# %% [markdown]
# <a href="https://colab.research.google.com/github/VENKAT-MANEESH-KANCHARLA/Python_lab/blob/main/NumPy_Practice_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NumPy Practice Exercises
#
# Solve each question in the code cell below it. Do not just re-run the lab examples — use **different numbers/data** than what was shown in class so you are actually writing the logic yourself.
#
# Run each cell with **Shift + Enter** and check that your output makes sense before moving to the next question.

# %% [markdown]
# ### Q1. Creating a 1-D array
# Create a 1-D NumPy array containing 6 numbers of your choice. Print the array and print its type using `type()`.

# %%
# Write your code here

# %% [markdown]
# ### Q2. Creating a 2-D array
# Create a 2-D NumPy array with 3 rows and 2 columns (any numbers). Print the array.

# %%
# Write your code here

# %% [markdown]
# ### Q3. Creating a 3-D array
# Create a 3-D NumPy array made up of two 2x3 matrices (2 blocks, each with 2 rows and 3 columns). Print the array.

# %%
# Write your code here

# %% [markdown]
# ### Q4. Checking the number of dimensions
# Using the three arrays you created in Q1, Q2, and Q3, print the number of dimensions of each using the `.ndim` attribute.

# %%
# Write your code here

# %% [markdown]
# ### Q5. Accessing elements with indexing
# Create a 2-D array with 2 rows and 5 columns of your own numbers.
# 1. Print the 3rd element of the 1st row using positive indexing.
# 2. Print the last element of the 2nd row using **negative** indexing.

# %%
# Write your code here

# %% [markdown]
# ### Q6. Accessing elements in a 3-D array
# Using the 3-D array you created in Q3, access and print one specific element using three indices, e.g. `arr[block, row, col]`.

# %%
# Write your code here

# %% [markdown]
# ### Q7. Checking data type
# Create one NumPy array of integers and one NumPy array that contains at least one decimal number. Print the `.dtype` of each and explain in a comment why they are different.

# %%
# Write your code here

# %% [markdown]
# ### Q8. Copy vs View
# Create a 1-D array. Make a **copy** of it using `.copy()` and a **view** of it using `.view()`. Change the first element of the original array, then print the original array, the copy, and the view. In a comment, explain what you observe and why.

# %%
# Write your code here

# %% [markdown]
# ### Q9. Shape of an array
# 1. Create a 2-D array with 3 rows and 4 columns and print its `.shape`.
# 2. Create a 1-D array of 4 numbers with `ndmin=5` and print both the array and its shape.

# %%
# Write your code here

# %% [markdown]
# ### Q10. Reshaping arrays
# Create a 1-D array with 15 elements. Reshape it into a 2-D array with 3 rows and 5 columns using `.reshape()`. Print the result.

# %%
# Write your code here

# %% [markdown]
# ### Q11. Linear algebra with NumPy
# Solve the following system of equations using `np.linalg.solve()`:
#
# 2x + y = 11
#
# x + 3y = 18
#
# Print the values of x and y.

# %%
# Write your code here

# %% [markdown]
# ### Q12. arange, zeros, and ones
# 1. Use `np.zeros()` to create a 4x2 array of zeros.
# 2. Use `np.ones()` to create a 3x3 array of ones.
# 3. Use `np.arange()` to create an array of numbers from 5 to 30 with a step of 5.
#
# Print all three.

# %%
# Write your code here

# %% [markdown]
# ### Q13. Why NumPy is faster than plain Python
# Create two Python lists of 500,000 numbers each. Time how long it takes to add them element-by-element using a Python loop (or list comprehension). Then convert both lists to NumPy arrays and time how long it takes to add them using `+`. Print both times and, in a comment, state which was faster and roughly by how much.

# %%
# Write your code here

# %% [markdown]
# ### Q14. Vectors vs matrices
# Create a 1-D NumPy array representing a single customer's features: `[height_cm, weight_kg, age]` (make up your own values). Then create a 2-D NumPy array representing 4 different customers with the same 3 features each. Print the `.shape` and `.ndim` of both arrays.

# %%
# Write your code here

# %% [markdown]
# ### Q15. Indexing and slicing to build X and y
# Create a 2-D array with 6 rows and 3 columns, where the last column is a target label (0 or 1) and the first two columns are features (make up your own numbers).
# 1. Print the first 3 rows only.
# 2. Print only the first column, for all rows.
# 3. Split the array into `X` (all columns except the last) and `y` (only the last column), and print both.

# %%
# Write your code here

# %% [markdown]
# ### Q16. Vectorized operations and boolean masking
# Create a 1-D NumPy array of 8 exam scores (0-100) of your choice. Without using any loop:
# 1. Add 5 bonus marks to every score and print the result.
# 2. Print a boolean array showing which scores are 50 or above.
# 3. Print only the scores that are 50 or above using boolean masking.

# %%
# Write your code here
