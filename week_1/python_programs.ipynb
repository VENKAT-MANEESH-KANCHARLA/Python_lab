# %% [markdown]
# <a href="https://colab.research.google.com/github/VENKAT-MANEESH-KANCHARLA/Python_lab/blob/main/week_1/python_programs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input("enter anumber:"))
b=int(input("enter anumber:"))
c=int(input("enter a number:"))
if(a>b):
  max=a
elif(b>a):
  max=b
if(max>c):
  print("greater number number is ",max)
else:
  print("greater number is ",c)
# Out:
# enter anumber:4
# enter anumber:22
# enter a number:6
# greater number number is  22

# %%
a=int(input("enter anumber:"))
if(a%3==0 and a%5!=0):
   print("buzz")
elif(a%5==0 and a%3!=0):
    print("fizz")
elif(a%3==0 and a%5==0):
  print("fizzbuzz")

# %%
a=complex(input("entere a number"))
b=complex(input("enter anumber"))
c=complex(a,b)
print(c)

# %%
a=int(input())
b=int(input())
a,b=b,a
print(a)
print(b)

# %%
for x in range(0,10,2):
  print(x)
