# %% [markdown]
# <a href="https://colab.research.google.com/github/VENKAT-MANEESH-KANCHARLA/Python_lab/blob/main/pythonlab7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
b=20
print(a,b)
def func():
  c=100
  a=110
  print(c)
  print(a,b)
func()
print(a,b)
# Out:
# 10 20
# 100
# 110 20
# 10 20

# %%
a=10
b=20
print(a,b)
def func():
  c=100
  global a
  a=110
  print(c)
  print(a,b)
func()
print(a,b)
# Out:
# 10 20
# 100
# 110 20
# 110 20

# %% [markdown]
# TUPLES,SETS AND DICTIONARIES

# %%
import sys
l=[]
t=[]
print(sys.get)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2898/278701329.py in <cell line: 0>()
#       2 l=[]
#       3 t=[]
# ----> 4 print(sys.get)
#
# AttributeError: module 'sys' has no attribute 'get'
